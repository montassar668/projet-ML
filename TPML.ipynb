# %% [markdown]
# <a href="https://colab.research.google.com/github/montassar668/projet-ML/blob/main/TPML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
data_to_load = files.upload()
import io
df_test = pd.read_csv(io.BytesIO(data_to_load['Test_v2.csv']))
# Out:
#      <input type="file" id="files-9990791e-b333-4955-ab10-4b2c3e4f14ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9990791e-b333-4955-ab10-4b2c3e4f14ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Test_v2.csv to Test_v2 (1).csv

# %%
from google.colab import files
data_to_load = files.upload()
import io
df_Train = pd.read_csv(io.BytesIO(data_to_load['Train_v2.csv']))
# Out:
#      <input type="file" id="files-eb019c1a-d499-420f-ba09-c6e967396ec5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eb019c1a-d499-420f-ba09-c6e967396ec5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Train_v2.csv to Train_v2 (1).csv

# %%
df_test
# Out:
#       country  ...                      job_type
# 0       Kenya  ...  Formally employed Government
# 1       Kenya  ...     Formally employed Private
# 2       Kenya  ...          Remittance Dependent
# 3       Kenya  ...          Remittance Dependent
# 4       Kenya  ...          Remittance Dependent
# ...       ...  ...                           ...
# 10081  Uganda  ...                 Self employed
# 10082  Uganda  ...                 Self employed
# 10083  Uganda  ...                  Other Income
# 10084  Uganda  ...                 Self employed
# 10085  Uganda  ...                  Other Income
#
# [10086 rows x 12 columns]

# %%
df_test.gender_of_respondent.value_counts().plot.bar(color='Y')

# %%
df_test.relationship_with_head.value_counts().plot.bar(color='gold')

# %%
df_test.cellphone_access.value_counts().plot.bar(color='C')

# %%
df_Train
# Out:
#       country  year  ...                  education_level                   job_type
# 0       Kenya  2018  ...              Secondary education              Self employed
# 1       Kenya  2018  ...              No formal education       Government Dependent
# 2       Kenya  2018  ...  Vocational/Specialised training              Self employed
# 3       Kenya  2018  ...                Primary education  Formally employed Private
# 4       Kenya  2018  ...                Primary education        Informally employed
# ...       ...   ...  ...                              ...                        ...
# 23519  Uganda  2018  ...              No formal education               Other Income
# 23520  Uganda  2018  ...              Secondary education               Other Income
# 23521  Uganda  2018  ...                Primary education               Other Income
# 23522  Uganda  2018  ...              Secondary education              Self employed
# ...

# %%
df_Train.bank_account.value_counts().plot.bar(color='lightcoral');

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10086 entries, 0 to 10085
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 10086 non-null  object
#  1   year                    10086 non-null  int64
#  2   uniqueid                10086 non-null  object
#  3   location_type           10086 non-null  object
#  4   cellphone_access        10086 non-null  object
#  5   household_size          10086 non-null  int64
#  6   age_of_respondent       10086 non-null  int64
#  7   gender_of_respondent    10086 non-null  object
#  8   relationship_with_head  10086 non-null  object
#  9   marital_status          10086 non-null  object
#  10  education_level         10086 non-null  object
#  11  job_type                10086 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 945.7+ KB

# %%
df_Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23524 non-null  object
#  1   year                    23524 non-null  int64
#  2   uniqueid                23524 non-null  object
#  3   bank_account            23524 non-null  object
#  4   location_type           23524 non-null  object
#  5   cellphone_access        23524 non-null  object
#  6   household_size          23524 non-null  int64
#  7   age_of_respondent       23524 non-null  int64
#  8   gender_of_respondent    23524 non-null  object
#  9   relationship_with_head  23524 non-null  object
#  10  marital_status          23524 non-null  object
#  11  education_level         23524 non-null  object
#  12  job_type                23524 non-null  object
# dtypes: int64(3), object(10)
# memory usage: 2.3+ MB

# %%
df1_test_m = df_test.groupby(by=["gender_of_respondent"]).get_group("Male")
df1_test_m
# Out:
#       country  ...                      job_type
# 0       Kenya  ...  Formally employed Government
# 1       Kenya  ...     Formally employed Private
# 4       Kenya  ...          Remittance Dependent
# 9       Kenya  ...           Farming and Fishing
# 10      Kenya  ...          Remittance Dependent
# ...       ...  ...                           ...
# 10076  Uganda  ...                 Self employed
# 10080  Uganda  ...                 Self employed
# 10082  Uganda  ...                 Self employed
# 10083  Uganda  ...                  Other Income
# 10085  Uganda  ...                  Other Income
#
# [4239 rows x 12 columns]

# %%
df1_test_f = df_test.groupby(by=["gender_of_respondent"]).get_group("Female")
df1_test_f
# Out:
#       country  year  ...                  education_level              job_type
# 2       Kenya  2018  ...              No formal education  Remittance Dependent
# 3       Kenya  2018  ...                Primary education  Remittance Dependent
# 5       Kenya  2018  ...                Primary education         Self employed
# 6       Kenya  2018  ...                Primary education   Informally employed
# 7       Kenya  2018  ...  Vocational/Specialised training         Self employed
# ...       ...   ...  ...                              ...                   ...
# 10077  Uganda  2018  ...                Primary education         Self employed
# 10078  Uganda  2018  ...                Primary education         Self employed
# 10079  Uganda  2018  ...              Secondary education          Other Income
# 10081  Uganda  2018  ...                Primary education         Self employed
# 10084  Uganda  2018  ...                Primary education         Self employed
#
# ...

# %%
df1_test_m.shape
# Out:
# (4239, 12)

# %%
df1_test_f.shape
# Out:
# (5847, 12)

# %%
df1_test_m.sort_values(by='age_of_respondent')
# Out:
#         country  year  ...      education_level              job_type
# 10085    Uganda  2018  ...  Secondary education          Other Income
# 6127     Rwanda  2016  ...    Primary education         Self employed
# 3498     Rwanda  2016  ...    Primary education  Remittance Dependent
# 9603     Uganda  2018  ...    Primary education             No Income
# 9061   Tanzania  2017  ...  No formal education   Informally employed
# ...         ...   ...  ...                  ...                   ...
# 102       Kenya  2018  ...  No formal education  Remittance Dependent
# 8790   Tanzania  2017  ...  No formal education  Remittance Dependent
# 3160     Rwanda  2016  ...  No formal education   Farming and Fishing
# 9926     Uganda  2018  ...  No formal education             No Income
# 377       Kenya  2018  ...  No formal education   Farming and Fishing
#
# [4239 rows x 12 columns]

# %%
df1_test_f.sort_values(by='age_of_respondent')
# Out:
#        country  year  ...      education_level              job_type
# 4230    Rwanda  2016  ...  Secondary education   Farming and Fishing
# 7887  Tanzania  2017  ...  Secondary education  Remittance Dependent
# 2580     Kenya  2018  ...    Primary education  Remittance Dependent
# 2582     Kenya  2018  ...    Primary education  Remittance Dependent
# 7861  Tanzania  2017  ...  Secondary education  Remittance Dependent
# ...        ...   ...  ...                  ...                   ...
# 104      Kenya  2018  ...  No formal education  Remittance Dependent
# 2279     Kenya  2018  ...  No formal education          Other Income
# 9110  Tanzania  2017  ...  No formal education             No Income
# 4904    Rwanda  2016  ...  No formal education  Remittance Dependent
# 6594  Tanzania  2017  ...    Primary education  Government Dependent
#
# [5847 rows x 12 columns]

# %%
df_test.isnull()
# Out:
#        country   year  uniqueid  ...  marital_status  education_level  job_type
# 0        False  False     False  ...           False            False     False
# 1        False  False     False  ...           False            False     False
# 2        False  False     False  ...           False            False     False
# 3        False  False     False  ...           False            False     False
# 4        False  False     False  ...           False            False     False
# ...        ...    ...       ...  ...             ...              ...       ...
# 10081    False  False     False  ...           False            False     False
# 10082    False  False     False  ...           False            False     False
# 10083    False  False     False  ...           False            False     False
# 10084    False  False     False  ...           False            False     False
# 10085    False  False     False  ...           False            False     False
#
# ...

# %%
df_test.isnull().sum()
# Out:
# country                   0
# year                      0
# uniqueid                  0
# location_type             0
# cellphone_access          0
# household_size            0
# age_of_respondent         0
# gender_of_respondent      0
# relationship_with_head    0
# marital_status            0
# education_level           0
# job_type                  0
# dtype: int64

# %%
df_Train.isnull()
# Out:
#        country   year  uniqueid  ...  marital_status  education_level  job_type
# 0        False  False     False  ...           False            False     False
# 1        False  False     False  ...           False            False     False
# 2        False  False     False  ...           False            False     False
# 3        False  False     False  ...           False            False     False
# 4        False  False     False  ...           False            False     False
# ...        ...    ...       ...  ...             ...              ...       ...
# 23519    False  False     False  ...           False            False     False
# 23520    False  False     False  ...           False            False     False
# 23521    False  False     False  ...           False            False     False
# 23522    False  False     False  ...           False            False     False
# 23523    False  False     False  ...           False            False     False
#
# ...

# %%
df_Train.isnull().sum()
# Out:
# country                   0
# year                      0
# uniqueid                  0
# bank_account              0
# location_type             0
# cellphone_access          0
# household_size            0
# age_of_respondent         0
# gender_of_respondent      0
# relationship_with_head    0
# marital_status            0
# education_level           0
# job_type                  0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
lc = LabelEncoder()
df_test['cellphone_access'] = lc.fit_transform(df_test['cellphone_access'])
df_test['gender_of_respondent'] = lc.fit_transform(df_test['gender_of_respondent'])
df_test['location_type'] = lc.fit_transform(df_test['location_type'])
df_test
# Out:
#       country  ...                      job_type
# 0       Kenya  ...  Formally employed Government
# 1       Kenya  ...     Formally employed Private
# 2       Kenya  ...          Remittance Dependent
# 3       Kenya  ...          Remittance Dependent
# 4       Kenya  ...          Remittance Dependent
# ...       ...  ...                           ...
# 10081  Uganda  ...                 Self employed
# 10082  Uganda  ...                 Self employed
# 10083  Uganda  ...                  Other Income
# 10084  Uganda  ...                 Self employed
# 10085  Uganda  ...                  Other Income
#
# [10086 rows x 12 columns]

# %%
df_Train['bank_account'] = lc.fit_transform(df_Train['bank_account'])
df_Train['cellphone_access'] = lc.fit_transform(df_Train['cellphone_access'])
df_Train['gender_of_respondent'] = lc.fit_transform(df_Train['gender_of_respondent'])
df_Train['location_type'] = lc.fit_transform(df_Train['location_type'])
df_Train
# Out:
#       country  year  ...                  education_level                   job_type
# 0       Kenya  2018  ...              Secondary education              Self employed
# 1       Kenya  2018  ...              No formal education       Government Dependent
# 2       Kenya  2018  ...  Vocational/Specialised training              Self employed
# 3       Kenya  2018  ...                Primary education  Formally employed Private
# 4       Kenya  2018  ...                Primary education        Informally employed
# ...       ...   ...  ...                              ...                        ...
# 23519  Uganda  2018  ...              No formal education               Other Income
# 23520  Uganda  2018  ...              Secondary education               Other Income
# 23521  Uganda  2018  ...                Primary education               Other Income
# 23522  Uganda  2018  ...              Secondary education              Self employed
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10086 entries, 0 to 10085
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 10086 non-null  object
#  1   year                    10086 non-null  int64
#  2   uniqueid                10086 non-null  object
#  3   location_type           10086 non-null  int64
#  4   cellphone_access        10086 non-null  int64
#  5   household_size          10086 non-null  int64
#  6   age_of_respondent       10086 non-null  int64
#  7   gender_of_respondent    10086 non-null  int64
#  8   relationship_with_head  10086 non-null  object
#  9   marital_status          10086 non-null  object
#  10  education_level         10086 non-null  object
#  11  job_type                10086 non-null  object
# dtypes: int64(6), object(6)
# memory usage: 945.7+ KB

# %%
df_Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23524 non-null  object
#  1   year                    23524 non-null  int64
#  2   uniqueid                23524 non-null  object
#  3   bank_account            23524 non-null  int64
#  4   location_type           23524 non-null  int64
#  5   cellphone_access        23524 non-null  int64
#  6   household_size          23524 non-null  int64
#  7   age_of_respondent       23524 non-null  int64
#  8   gender_of_respondent    23524 non-null  int64
#  9   relationship_with_head  23524 non-null  object
#  10  marital_status          23524 non-null  object
#  11  education_level         23524 non-null  object
#  12  job_type                23524 non-null  object
# dtypes: int64(7), object(6)
# memory usage: 2.3+ MB
